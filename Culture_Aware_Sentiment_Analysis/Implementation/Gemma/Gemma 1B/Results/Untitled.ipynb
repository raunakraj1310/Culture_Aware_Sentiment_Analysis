# %%
import os
os.getcwd()
# Out:
# '/mnt/sda1/osint_intern/SA_Group/Raunak/Culture_Aware_Sentiment_Analysis/Implementation/Gemma/Gemma 1B/Results'

# %%
import pandas as pd
import glob
import os


print(os.getcwd())
csv_files=glob.glob(os.path.join(os.getcwd(),"*.csv"))
df=pd.concat([pd.read_csv(file) for file in csv_files],ignore_index=True)
df.to_csv("combined.csv",index=False)
print(df.shape)
# Out:
# /mnt/sda1/osint_intern/SA_Group/Raunak/Culture_Aware_Sentiment_Analysis/Implementation/Gemma/Gemma 1B/Results
# (11832, 4)
