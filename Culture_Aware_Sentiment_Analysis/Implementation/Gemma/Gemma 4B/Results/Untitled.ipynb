# %%
import os
print(os.getcwd())
# Out:
# /mnt/sda1/osint_intern/SA_Group/Raunak/Culture_Aware_Sentiment_Analysis/Implementation/Gemma/Gemma 4B/Results

# %%
import pandas as pd
import glob
import os


print(os.getcwd())
csv_files=glob.glob(os.path.join(os.getcwd(),"*.csv"))
df=pd.concat([pd.read_csv(file) for file in csv_files],ignore_index=True)
df.to_csv("combined.csv",index=False)
print(df.shape)
# Out:
# (11832, 4)

# %%
os.listdir()
# Out:
# ['Western_Cultural_Region_Gemma_4B.csv',
#  'Northern_Cultural_Region_Gemma_4B.csv',
#  'Southern_Cultural_Region_Gemma_4B.csv',
#  'Northeastern_Cultural_Region_Gemma_4B.csv',
#  'Eastern_Cultural_Region_Gemma_4B.csv',
#  'Central_Cultural_Region_Gemma_4B.csv',
#  '.ipynb_checkpoints',
#  'Untitled.ipynb',
#  'Gemma_4B_Output.csv']

# %%
os.rename('combined.csv',"Gemma_4B_Output.csv")
