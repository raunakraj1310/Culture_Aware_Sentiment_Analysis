# %%
#Analysis For Gemma

# %%
import pandas as pd
dfg=pd.read_csv("Gemma_1B_Output.csv")

# %%
dfg
# Out:
#                                                 Sentence  \
# 0      कई नवविवाहित जोड़े शादी के बाद अपने विस्तारित ...
# 1      कई नवविवाहित जोड़े शादी के बाद अपने विस्तारित ...
# 2      छात्र अक्सर अपने शिक्षक के चरणों को छूकर आशीर्...
# 3      छात्र अक्सर अपने शिक्षक के चरणों को छूकर आशीर्...
# 4      उसे अपने परिवार की देखभाल के लिए अपनी नौकरी छो...
# ...                                                  ...
# 11827  उत्तराखंड के लोग त्योहारों और अन्य उत्सवों के ...
# 11828  उत्तराखंड के लोग त्योहारों और अन्य उत्सवों के ...
# 11829  उत्तराखंड में सिंगोड़ी, बाल-मिठाई और मलाई लड्डू...
# 11830  उत्तराखंड में सिंगोड़ी, बाल-मिठाई और मलाई लड्डू...
# 11831  उत्तराखंड में सिंगोड़ी, बाल-मिठाई और मलाई लड्डू...
#
#                         Region           State Sentiment
# 0      Central Cultural Region  Madhya Pradesh   neutral
# 1      Central Cultural Region    Chhattisgarh   neutral
# 2      Central Cultural Region  Madhya Pradesh  positive
# 3      Central Cultural Region    Chhattisgarh  positive
# 4      Central Cultural Region  Madhya Pradesh  negative
# ...                        ...             ...       ...
# 11827  Western Cultural Region   Daman and Diu  positive
# 11828  Western Cultural Region     Maharashtra  positive
# 11829  Western Cultural Region   Daman and Diu  positive
# 11830  Western Cultural Region     Maharashtra  positive
# 11831  Western Cultural Region         Gujarat  positive
#
# [11832 rows x 4 columns]

# %%
dfg["Sentiment"].value_counts()
# Out:
# Sentiment
# neutral        5223
# positive       4105
# negative       2383
# PARSE_ERROR     121
# Name: count, dtype: int64

# %%
#For Gemma 4B

# %%
dfg4b=pd.read_csv("Gemma_4B_Output.csv")
dfg4b["Sentiment"].value_counts()
# Out:
# Sentiment
# neutral        5211
# positive       4117
# negative       2390
# PARSE_ERROR     114
# Name: count, dtype: int64

# %%
dfgl=pd.read_csv("LLama 1B_Output.csv")
dfgl["Sentiment"].value_counts()
# Out:
# Sentiment
# positive    8077
# negative    3755
# Name: count, dtype: int64

# %%
import os
os.listdir()
# Out:
# ['Gemma_4B_Output.csv',
#  'Untitled Folder',
#  'Gemma_1B_Output.csv',
#  '.ipynb_checkpoints',
#  'Mistral_Output.csv',
#  'Qwen_3.5_1B_output.csv',
#  'Untitled.ipynb',
#  'Gemma_4B_reassesment.csv',
#  'Gemma_1B_reassment.csv',
#  'LLama 1B_Output.csv']

# %%
df1,df2,df3,df4,df5=pd.read_csv('Gemma_4B_Output.csv',),pd.read_csv('Gemma_1B_Output.csv'),pd.read_csv('Mistral_Output.csv'),pd.read_csv('LLama 1B_Output.csv'),pd.read_csv('Qwen_3.5_1B_output.csv')

# %%
df4
# Out:
#                                                 Sentence  \
# 0      कई नवविवाहित जोड़े शादी के बाद अपने विस्तारित ...
# 1      कई नवविवाहित जोड़े शादी के बाद अपने विस्तारित ...
# 2      कई नवविवाहित जोड़े शादी के बाद अपने विस्तारित ...
# 3      कई नवविवाहित जोड़े शादी के बाद अपने विस्तारित ...
# 4      कई नवविवाहित जोड़े शादी के बाद अपने विस्तारित ...
# ...                                                  ...
# 11827  उत्तराखंड में सिंगोड़ी, बाल-मिठाई और मलाई लड्डू...
# 11828  उत्तराखंड में सिंगोड़ी, बाल-मिठाई और मलाई लड्डू...
# 11829  उत्तराखंड में सिंगोड़ी, बाल-मिठाई और मलाई लड्डू...
# 11830  उत्तराखंड में सिंगोड़ी, बाल-मिठाई और मलाई लड्डू...
# 11831  उत्तराखंड में सिंगोड़ी, बाल-मिठाई और मलाई लड्डू...
#
#                              Region              State Sentiment
# 0          Northern Cultural Region   Himachal Pradesh  positive
# 1          Northern Cultural Region            Haryana  positive
# 2          Northern Cultural Region        Uttarakhand  positive
# 3          Southern Cultural Region     Andhra Pradesh  positive
# 4          Southern Cultural Region          Karnataka  positive
# ...                             ...                ...       ...
# 11827       Central Cultural Region     Madhya Pradesh  positive
# 11828       Central Cultural Region       Chhattisgarh  positive
# 11829  Northeastern Cultural Region            Manipur  positive
# 11830  Northeastern Cultural Region          Meghalaya  positive
# 11831  Northeastern Cultural Region  Arunachal Pradesh  positive
#
# [11832 rows x 4 columns]

# %%
df5
# Out:
#                                                    Hindi  \
# 0      अंडमान और निकोबार द्वीप समूह के व्यंजनों में स...
# 1      अंडमान और निकोबार द्वीप समूह के व्यंजनों में स...
# 2      अंडमान और निकोबार द्वीप समूह के व्यंजनों में स...
# 3      अंडमान और निकोबार द्वीप समूह के व्यंजनों में स...
# 4      अंडमान और निकोबार द्वीप समूह के व्यंजनों में स...
# ...                                                  ...
# 11827  हैदराबादी व्यंजनों में बिरयानी, हलीम, बघारा बै...
# 11828  हैदराबादी व्यंजनों में बिरयानी, हलीम, बघारा बै...
# 11829  हैदराबादी व्यंजनों में बिरयानी, हलीम, बघारा बै...
# 11830  हैदराबादी व्यंजनों में बिरयानी, हलीम, बघारा बै...
# 11831  हैदराबादी व्यंजनों में बिरयानी, हलीम, बघारा बै...
#
#                          Region                   State Sentiment
# 0       Central Cultural Region            Chhattisgarh  positive
# 1       Central Cultural Region          Madhya_Pradesh  positive
# 2       Eastern Cultural Region                   Bihar  positive
# 3       Eastern Cultural Region               Jharkhand  positive
# 4       Eastern Cultural Region             West_Bengal  positive
# ...                         ...                     ...       ...
# 11827  Southern Cultural Region             Lakshadweep   neutral
# 11828  Southern Cultural Region              Tamil_Nadu   neutral
# 11829   Western Cultural Region  Dadra_and_Nagar_Haveli   neutral
# 11830   Western Cultural Region           Daman_and_Diu   neutral
# 11831   Western Cultural Region               Rajasthan   neutral
#
# [11832 rows x 4 columns]

# %%
sentiment_df=pd.DataFrame({"Gemma_4B": df1["Sentiment"],
    "Gemma_1B": df2["Sentiment"],
    "Mistral": df3["Sentiment"],
    "Llama_1B": df4["Sentiment"],
    "Qwen_3.5_1B": df5["Sentiment"]})

# %%
sentiment_df.describe()
# Out:
#        Gemma_4B Gemma_1B   Mistral  Llama_1B Qwen_3.5_1B
# count     11832    11832     11832     11832       11832
# unique        4        4         3         2           3
# top     neutral  neutral  positive  positive     neutral
# freq       5211     5223      8004      8077        8434

# %%
sentiment_df
# Out:
#        Gemma_4B  Gemma_1B   Mistral  Llama_1B Qwen_3.5_1B
# 0       neutral   neutral  positive  positive    positive
# 1       neutral   neutral  positive  positive    positive
# 2       neutral  positive  positive  positive    positive
# 3      positive  positive  positive  positive    positive
# 4      positive  negative  positive  positive    positive
# ...         ...       ...       ...       ...         ...
# 11827   neutral  positive   neutral  positive     neutral
# 11828  positive  positive   neutral  positive     neutral
# 11829  positive  positive   neutral  positive     neutral
# 11830  positive  positive  positive  positive     neutral
# 11831  positive  positive   neutral  positive     neutral
#
# [11832 rows x 5 columns]

# %%
sentiment_df.value_counts()
# Out:
# Gemma_4B     Gemma_1B     Mistral   Llama_1B  Qwen_3.5_1B
# neutral      neutral      positive  positive  neutral        879
#              positive     positive  positive  neutral        680
# positive     neutral      positive  positive  neutral        655
#              positive     positive  positive  neutral        560
# neutral      negative     positive  positive  neutral        410
#                                                             ...
# PARSE_ERROR  negative     neutral   positive  positive         1
#              neutral      positive  negative  negative         1
#                           neutral   negative  negative         1
# positive     neutral      neutral   negative  negative         1
#              PARSE_ERROR  positive  positive  negative         1
# Name: count, Length: 199, dtype: int64

# %%
sentiment_df.apply(pd.Series.value_counts)
# Out:
#              Gemma_4B  Gemma_1B  Mistral  Llama_1B  Qwen_3.5_1B
# PARSE_ERROR       114       121      NaN       NaN          NaN
# negative         2390      2383   1131.0    3755.0        554.0
# neutral          5211      5223   2697.0       NaN       8434.0
# positive         4117      4105   8004.0    8077.0       2844.0

# %%
#Parse Error

# %%
#Parse Error in Gemma_4B

# %%
PE1=df1[df1["Sentiment"]=="PARSE_ERROR"]
PE1.to_csv("Gemma_4B_reassesment.csv",index=False)

# %%
os.getcwd()
# Out:
# '/mnt/sda1/osint_intern/SA_Group/Raunak/Culture_Aware_Sentiment_Analysis/Analysis'

# %%
#Parse Error in Gemma_4B

# %%
PE2=df2[df2["Sentiment"]=="PARSE_ERROR"]
PE2.to_csv("Gemma_1B_reassment.csv",index=False)
