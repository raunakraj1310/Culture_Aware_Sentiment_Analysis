# %%
import os, pandas as pd

# %%
df=pd.read_csv("Gemma_1B_Output.csv")
df2=pd.read_csv("/mnt/sda1/osint_intern/SA_Group/Raunak/Culture_Aware_Sentiment_Analysis/Implementation/Gemma/Gemma 1B/Gemma 1Ball_reassesd_predictions.csv")

# %%
df.columns
# Out:
# Index(['Sentence', 'Region', 'State', 'Sentiment'], dtype='str')

# %%
os.listdir()
# Out:
# ['Gemma_4B_Output.csv',
#  'Untitled Folder',
#  'Gemma_1B_Output.csv',
#  '.ipynb_checkpoints',
#  'Mistral_Output.csv',
#  'Qwen_3.5_1B_output.csv',
#  'Gemma_1B_reassment.csv',
#  'LLama 1B_Output.csv',
#  'Analysis.ipynb',
#  'all_reassesd_gemma_4B_predictions.csv',
#  'Untitled.ipynb']

# %%
df2=pd.read_csv("/mnt/sda1/osint_intern/SA_Group/Raunak/Culture_Aware_Sentiment_Analysis/Implementation/Gemma/Gemma 1B/Gemma 1Ball_reassesd_predictions.csv")
df2.columns
# Out:
# Index(['Sentence', 'Region', 'State', 'Sentiment'], dtype='str')

# %%
df=df.set_index(['Sentence', 'Region', 'State'])
df2=df2.set_index(['Sentence', 'Region', 'State'])
df.update(df2[["Sentiment"]])
df=df.reset_index()

# %%
df.describe()
# Out:
#                                                  Sentence  \
# count                                               11832
# unique                                                696
# top     कई नवविवाहित जोड़े शादी के बाद अपने विस्तारित ...
# freq                                                   17
#
#                          Region           State Sentiment
# count                     11832           11832     11832
# unique                        6              37         3
# top     Eastern Cultural Region  Madhya Pradesh   neutral
# freq                       2088             696      5275

# %%
os.rename("Untitled.ipynb","Gemma_1B_Correction.ipynb")

# %%
print(os.getcwd())
os.listdir()
# Out:
# /mnt/sda1/osint_intern/SA_Group/Raunak/Culture_Aware_Sentiment_Analysis/Analysis
# ['Gemma_4B_Output.csv',
#  'Untitled Folder',
#  'Gemma_1B_Output.csv',
#  '.ipynb_checkpoints',
#  'Mistral_Output.csv',
#  'Qwen_3.5_1B_output.csv',
#  'Gemma_1B_reassment.csv',
#  'LLama 1B_Output.csv',
#  'Analysis.ipynb',
#  'all_reassesd_gemma_4B_predictions.csv',
#  'Gemma_1B_Correction.ipynb',
#  'Untitled.ipynb']

# %%
df.to_csv("Gemma_1B_Output.csv")
